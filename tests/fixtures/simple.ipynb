# %% [markdown]
# # Data Analysis
# Load and explore the dataset.

# %%
import pandas as pd
df = pd.read_csv("data.csv")
print(df.head())
# Out:
#    col_a col_b  col_c
# 0      1   foo   3.14
# 1      2   bar   2.71

# %%
df.describe()
